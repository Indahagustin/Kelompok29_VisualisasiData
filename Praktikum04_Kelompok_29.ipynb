# %% [markdown]
# <a href="https://colab.research.google.com/github/Indahagustin/Kelompok29_VisualisasiData/blob/main/Praktikum04_Kelompok_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM BAR CHART**

# %% [markdown]
# **KELOMPOK 29** :
# * Amirullah (0110222106)
# * Indah Agustin (0110222250)
# * Miftahul Jannah (0110222101)

# %%
import matplotlib.pyplot as plt


# Data
jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science',
]
jumlah_mahasiswa = [120, 150, 100, 80]

# Membuat basic bar chart
plt.bar(jurusan, jumlah_mahasiswa, color=['blue', 'orange', 'green', 'red'])
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.title('Jumlah Mahasiswa per Jurusan')
plt.show()

# %% [markdown]
# **A. Basic Bar Chart dengan Matplotlib**

# %%
import matplotlib.pyplot as plt


# Data
jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science',
]
jumlah_mahasiswa = [120, 150, 100, 80]

# Membuat basic bar chart
plt.bar(jurusan, jumlah_mahasiswa, color=['blue', 'orange', 'green', 'red'])
plt.title('Jumlah Mahasiswa per Jurusan')
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle= '--', alpha=0.7)
plt.show()

# %% [markdown]
# **B. Kustomisasi Basic Bar Chart**

# %%
import matplotlib.pyplot as plt


# Data
jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science',
]
jumlah_mahasiswa = [120, 150, 100, 80]

# Membuat basic bar chart
plt.bar(jurusan, jumlah_mahasiswa, color=['blue', 'orange', 'green', 'red'])
plt.title('Jumlah Mahasiswa per Jurusan')
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=45)

# Menambahkan label pada batang
for i, v in enumerate(jumlah_mahasiswa):
    plt.text(i, v + 2, str(v), ha='center')

plt.show()

# %% [markdown]
# **C. Multiple Bar Chart**

# %%
import matplotlib.pyplot as plt


# Data
jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science',
]
jumlah_mahasiswa = [120, 150, 100, 80]
jumlah_mahasiswa_2024 = [130, 160, 110, 90]

x = range(len(jurusan))
width = 0.4

plt.bar(x, jumlah_mahasiswa, width, label='2023', color='green')
plt.bar([p + width for p in x], jumlah_mahasiswa_2024, width=width, label='2024', color='lime')


plt.title('Jumlah Mahasiswa per Jurusan (2023 vs 2024)')
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=45)
plt.xticks([p + width/2 for p in x], jurusan)
plt.legend()

plt.show()

# %% [markdown]
# **D. Basic Bar Chart untuk Melihat Pola dan Tren**

# %%
from matplotlib import color_sequences
import matplotlib.pyplot as plt


# Data
jurusan = ['Ilmu Komputer', 'Teknik Informatika', 'Sistem Informasi', 'Data Science',]
tahun = {'2019', '2020', '2021', '2022', '2023'}
data = {
    'Ilmu Komputer': [120, 130, 140, 150, 160],
    'Teknik Informatika': [110, 120, 130, 140, 150],
    'Sistem Informasi': [100, 110, 120, 130, 140],
    'Data Science': [90, 100, 110, 120, 130],
}
width = 0.2
x = range(len(tahun))

# Visualisasi masing-masing jurusan
plt.bar(x, data['Ilmu Komputer'], width=width, label='Ilmu Komputer', color='Purple')
plt.bar([p + width for p in x],
        data['Sistem Informasi'], width=width, label='Sistem Informasi', color='pink')
plt.bar([p + width * 2 for p in x],
        data['Teknik Informatika'], width=width, label='Teknik Informatika', color='blue')
plt.bar([p + width * 3 for p in x],
        data['Data Science'], width=width, label='Data Science', color='skyblue')

# Detail Grafik
plt.title(' Tren Jumlah Mahasiswa per Jurusan (2019 - 2023)')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks([p + width for p in x], tahun)
plt.legend()

plt.show()
